# %%
import pandas as pd
import numpy as np

import json
from pprint import pprint

# %%
df = pd.read_csv('data/recipes.csv')

# %% [markdown]
# Exercise 7.1: create a list of unique id numbers

# %%
ids = list(df['id'].unique())

# %% [markdown]
# Exercise 7.2: create a list of unique indredients

# %%
ingredients = list(df.columns)[3:] # Создаем список уникальных значений ингредиентов

# %%
ingredients = list()
col = df.columns[3:]
for c in col:
    for x in df[c]:
        if (x == 1) and not (c in ingredients):
            ingredients.append(c)
display(ingredients)
# Out:
# ['romaine lettuce',
#  'black olives',
#  'grape tomatoes',
#  'garlic',
#  'pepper',
#  'purple onion',
#  'seasoning',
#  'garbanzo beans',
#  'feta cheese crumbles',
#  'plain flour',
#  'ground pepper',
#  'salt',
#  'tomatoes',
#  'ground black pepper',
#  'thyme',
#  'eggs',
#  'green tomatoes',
#  'yellow corn meal',
#  'milk',
#  'vegetable oil',
#  'mayonaise',
#  'cooking oil',
#  'green chilies',
#  'grilled chicken breasts',
#  'garlic powder',
#  'yellow onion',
#  'soy sauce',
#  'butter',
#  'chicken livers',
#  'water',
#  'wheat',
#  'black pepper',
#  'shallots',
#  'cornflour',
#  'cayenne pepper',
#  'onions',
#  'garlic paste',
#  'lemon juice',
#  'chili powder',
#  'passata',
#  'oil',
#  'ground cumin',
#  'boneless chicken skinless thigh',
#  'garam masala',
#  'double cream',
#  'natural yogurt',
#  'bay leaf',
#  'sugar',
#  'fresh ginger root',
#  'ground cinnamon',
#  'vanilla extract',
#  'ground ginger',
#  'powdered sugar',
#  'baking powder',
#  'olive oil',
#  'medium shrimp',
#  'chopped cilantro',
#  'jalapeno chilies',
#  'flat leaf parsley',
#  'skirt steak',
#  'white vinegar',
#  'sea salt',
#  'chorizo sausage',
#  'pistachio nuts',
#  'white almond bark',
#  'flour',
#  'almond extract',
#  'dried cranberries',
#  'fresh pineapple',
#  'pork',
#  'poblano peppers',
#  'corn tortillas',
#  'cheddar cheese',
#  'iceberg lettuce',
#  'lime',
#  'chopped cilantro fresh',
#  'chopped tomatoes',
#  'fresh basil',
#  'extra-virgin olive oil',
#  'kosher salt',
#  'pimentos',
#  'sweet pepper',
#  'dried oregano',
#  'sharp cheddar cheese',
#  'swiss cheese',
#  'provolone cheese',
#  'canola oil',
#  'mushrooms',
#  'sausages',
#  'low sodium soy sauce',
#  'fresh ginger',
#  'dry mustard',
#  'green beans',
#  'white pepper',
#  'sesame oil',
#  'scallions',
#  'Shaoxing wine',
#  'ground turkey',
#  'crushed red pepper flakes',
#  'corn starch',
#  'Italian parsley leaves',
#  'walnuts',
#  'hot red pepper flakes',
#  'fresh lemon juice',
#  'trout fillet',
#  'garlic cloves',
#  'chipotle chile',
#  'fine sea salt',
#  'fresh cilantro',
#  'ground coriander',
#  'plum tomatoes',
#  'avocado',
#  'lime juice',
#  'flank steak',
#  'fresh parmesan cheese',
#  'all-purpose flour',
#  'fat free less sodium chicken broth',
#  'chopped fresh chives',
#  'gruyere cheese',
#  'bacon slices',
#  'gnocchi',
#  'fat free milk',
#  'cooking spray',
#  'tumeric',
#  'vegetable stock',
#  'naan',
#  'red lentils',
#  'red chili peppers',
#  'spinach',
#  'sweet potatoes',
#  'greek yogurt',
#  'lemon curd',
#  'confectioners sugar',
#  'raspberries',
#  'italian seasoning',
#  'broiler-fryer chicken',
#  'zesty italian dressing',
#  'hot chili',
#  'asian fish sauce',
#  'red bell pepper',
#  'chicken broth',
#  'yellow squash',
#  'garlic chili sauce',
#  'sliced green onions',
#  'broccolini',
#  'fresh lime juice',
#  'cooked rice',
#  'chicken breasts',
#  'pork loin',
#  'roasted peanuts',
#  'hoisin sauce',
#  'creamy peanut butter',
#  'chopped fresh mint',
#  'thai basil',
#  'rice',
#  'rice noodles',
#  'beansprouts',
#  'roma tomatoes',
#  'low-fat mayonnaise',
#  'baking potatoes',
#  'spicy brown mustard',
#  'sesame seeds',
#  'red pepper',
#  'yellow peppers',
#  'extra firm tofu',
#  'broccoli',
#  'orange bell pepper',
#  'arrowroot powder',
#  'red curry paste',
#  'marinara sauce',
#  'linguine',
#  'capers',
#  'olives',
#  'lemon zest',
#  'lo mein noodles',
#  'light soy sauce',
#  'dried black mushrooms',
#  'chives',
#  'oyster sauce',
#  'dark soy sauce',
#  'peanuts',
#  'cabbage',
#  'herbs',
#  'fresh tomatoes',
#  'paprika',
#  'mango',
#  'stock',
#  'chile pepper',
#  'sliced mushrooms',
#  'sherry',
#  'grated parmesan cheese',
#  'heavy cream',
#  'spaghetti',
#  'cooked chicken',
#  'green bell pepper',
#  'egg roll wrappers',
#  'sweet and sour sauce',
#  'molasses',
#  'shredded cabbage',
#  'ground pork',
#  'carrots',
#  'flour tortillas',
#  'cheese',
#  'breakfast sausages',
#  'large eggs',
#  'boiling water',
#  'hot sauce',
#  'potatoes',
#  'bacon',
#  'fresh parsley',
#  'andouille sausage',
#  'cajun seasoning',
#  'peanut oil',
#  'celery',
#  'ground red pepper',
#  'shrimp',
#  'onion powder',
#  'firm tofu',
#  'turnips',
#  'palm sugar',
#  'sliced chicken',
#  'fish sauce',
#  'lime wedges',
#  'green papaya',
#  'chile powder',
#  'tamarind paste',
#  'chinese chives',
#  'crushed garlic',
#  'green onions',
#  'white sugar',
#  'dried basil',
#  'diced tomatoes',
#  'Johnsonville Andouille Dinner Sausage',
#  'parsley',
#  'jambalaya rice mix',
#  'worcestershire sauce',
#  'hot pepper sauce',
#  'creole seasoning',
#  'bread slices',
#  'great northern beans',
#  'sage leaves',
#  'chinese five-spice powder',
#  'chicken thighs',
#  'star anise',
#  'cream cheese',
#  'shredded cheddar cheese',
#  'black-eyed peas',
#  'tortilla chips',
#  'collard greens',
#  'ham hock',
#  'chicken stock',
#  'apple cider',
#  'freshly ground pepper',
#  'bay leaves',
#  'rib',
#  'light brown sugar',
#  'large garlic cloves',
#  'Oscar Mayer Deli Fresh Smoked Ham',
#  'hoagie rolls',
#  'salami',
#  'giardiniera',
#  'mozzarella cheese',
#  'pepperoni',
#  'ice cubes',
#  'club soda',
#  'white rum',
#  'turbinado',
#  'enchilada sauce',
#  'picante sauce',
#  'green pepper',
#  'canned black beans',
#  'shredded lettuce',
#  'sour cream',
#  'salmon fillets',
#  'cumin seed',
#  'curry powder',
#  'serrano chile',
#  'sauce',
#  'chicken breast halves',
#  'lettuce leaves',
#  'chopped onion',
#  'mandarin oranges',
#  'orange liqueur',
#  'yellow cake mix',
#  'frosting',
#  'fennel bulb',
#  'lemon olive oil',
#  'grapefruit juice',
#  'white cornmeal',
#  'bacon drippings',
#  'buttermilk',
#  'crab boil',
#  'old bay seasoning',
#  'crawfish',
#  'sirloin',
#  'mirin',
#  'corn oil',
#  'glass noodles',
#  'sake',
#  'shiitake',
#  'napa cabbage',
#  'whipping cream',
#  'extra sharp cheddar cheese',
#  'quickcooking grits',
#  'monterey jack',
#  'crushed red pepper',
#  'mussels',
#  'basil',
#  'dry white wine',
#  'finely chopped onion',
#  'baking soda',
#  'honey',
#  'unsalted butter',
#  'lemon',
#  'pesto',
#  'white wine',
#  'bread crumbs',
#  'curry',
#  'low sodium beef broth',
#  'pickapeppa sauce',
#  'cold water',
#  'allspice',
#  'fresh thyme',
#  'ground beef',
#  'melted butter',
#  'matcha green tea powder',
#  'chopped walnuts',
#  'coarse salt',
#  'fenugreek',
#  'urad dal',
#  'white rice',
#  'pizza crust',
#  'part-skim mozzarella cheese',
#  'yukon gold potatoes',
#  'low-fat sour cream',
#  'leeks',
#  '1% low-fat milk',
#  'lemongrass',
#  'unsweetened coconut milk',
#  'peanut sauce',
#  'spareribs',
#  'tamari soy sauce',
#  'golden brown sugar',
#  'dry sherry',
#  'chicken legs',
#  'ghee',
#  'tomato paste',
#  'ground turmeric',
#  'cracked black pepper',
#  'minced beef',
#  'dried thyme',
#  'ginger',
#  'chillies',
#  'crushed tomatoes',
#  'fresh rosemary',
#  'boneless pork loin',
#  'pappardelle',
#  'coconut milk',
#  'eggplant',
#  'jasmine rice',
#  'Gochujang base',
#  'top round steak',
#  'rice vinegar',
#  'Taiwanese bok choy',
#  'vanilla',
#  'large egg yolks',
#  'orange juice concentrate',
#  'pumpkin purГ©e',
#  'marshmallow creme',
#  'toasted pecans',
#  'maple syrup',
#  'gingersnap',
#  'ground nutmeg',
#  'brown sugar',
#  'serrano ham',
#  'manchego cheese',
#  'dijon mustard',
#  'sourdough',
#  'membrillo',
#  'burger buns',
#  'panko breadcrumbs',
#  'chickpea flour',
#  'Sriracha',
#  'chickpeas',
#  'ground flaxseed',
#  'greens',
#  'tahini',
#  'ground cloves',
#  'whole nutmegs',
#  'ground cardamom',
#  'Italian bread',
#  'balsamic vinegar',
#  'sausage casings',
#  'shredded mozzarella cheese',
#  'roasted red peppers',
#  'penne pasta',
#  'saffron',
#  'warm water',
#  'preserved lemon',
#  'harissa',
#  'couscous',
#  'cayenne',
#  'fat skimmed chicken broth',
#  'pitted kalamata olives',
#  'fat',
#  'sweetened condensed milk',
#  'ice',
#  'espresso',
#  'fresh asparagus',
#  'pecans',
#  'crumbled blue cheese',
#  'chuck',
#  'hamburger buns',
#  'okra pods',
#  'watercress',
#  'self rising flour',
#  'softened butter',
#  'food colouring',
#  'Madeira',
#  'foie gras',
#  'demi-glace',
#  'sherry vinegar',
#  'white bread',
#  'Fuyu persimmons',
#  'egg bread',
#  'fenugreek leaves',
#  'black mustard seeds',
#  'amchur',
#  'coriander',
#  'fingerling potatoes',
#  'ramps',
#  'black peppercorns',
#  'cinnamon sticks',
#  'cardamom pods',
#  'coriander seeds',
#  'asiago',
#  'whole wheat pasta',
#  'sweet onion',
#  'chestnuts',
#  'granulated sugar',
#  'whole milk ricotta cheese',
#  'coffee ice cream',
#  'mascarpone',
#  'rum',
#  'semisweet chocolate',
#  'chestnut flour',
#  'baby spinach leaves',
#  'chopped garlic',
#  'large shrimp',
#  'barley',
#  'cooked ham',
#  'starchy potatoes',
#  'grated nutmeg',
#  'sirloin tip roast',
#  'steak',
#  'vegetable shortening',
#  'finely chopped fresh parsley',
#  'vinegar',
#  'caul fat',
#  'whole milk',
#  'heavy whipping cream',
#  'kahlГєa',
#  'instant espresso powder',
#  'epazote',
#  'radishes',
#  'oregano',
#  'white onion',
#  'hominy',
#  'tomatillos',
#  'pepitas',
#  'catfish fillets',
#  'basmati rice',
#  'cauliflower',
#  'cumin',
#  'blood orange',
#  'low salt chicken broth',
#  'white wine vinegar',
#  'tomato sauce',
#  'shredded carrots',
#  'english muffins, split and toasted',
#  'vegetable oil cooking spray',
#  'chopped green bell pepper',
#  'prawns',
#  'rice flour',
#  'seasoning salt',
#  'lasagna noodles',
#  'ranch dressing',
#  'evaporated milk',
#  'minced garlic',
#  'red wine vinegar',
#  'boneless chop pork',
#  'chile paste',
#  'lower sodium soy sauce',
#  'dark sesame oil',
#  'raisins',
#  'pearl barley',
#  'slivered almonds',
#  'chocolate bars',
#  'marshmallows',
#  'cinnamon graham crackers',
#  'chopped celery',
#  'mustard powder',
#  'cod',
#  'minced onion',
#  'dry bread crumbs',
#  'golden raisins',
#  'margarine',
#  'mace',
#  'brewed tea',
#  'candied orange peel',
#  'grated lemon zest',
#  'dried currants',
#  'rum extract',
#  'dark brown sugar',
#  'noodles',
#  'baby bok choy',
#  'black bean sauce',
#  'red potato',
#  'chinese rice wine',
#  'black beans',
#  'quinoa',
#  'frozen corn',
#  'vegetable broth',
#  'yellow bell pepper',
#  'orange',
#  'duck',
#  'dried mint flakes',
#  'penne rigate',
#  'feta cheese',
#  'ras el hanout',
#  'ground lamb',
#  'large egg whites',
#  '2% reduced-fat milk',
#  'napa cabbage leaves',
#  'chicken leg quarters',
#  'cucumber',
#  'long-grain rice',
#  'crusty bread',
#  'baby potatoes',
#  'smoked streaky bacon',
#  'piloncillo',
#  'ground allspice',
#  'hibiscus',
#  'fresh oregano',
#  'chocolate morsels',
#  'cream sweeten whip',
#  'instant espresso granules',
#  'chocolate covered coffee beans',
#  'unflavored gelatin',
#  'pound cake',
#  'pinenuts',
#  'zucchini',
#  'baby carrots',
#  'fresh basil leaves',
#  'asparagus spears',
#  'frozen peas',
#  'arborio rice',
#  'yellow crookneck squash',
#  'chipotles in adobo',
#  'instant white rice',
#  'cilantro leaves',
#  'red beans',
#  'skinless chicken thighs',
#  'lime zest',
#  'condensed cream of mushroom soup',
#  'condensed cream of chicken soup',
#  'lean ground beef',
#  'Mexican cheese blend',
#  'chunky salsa',
#  'taco seasoning mix',
#  'chorizo spanish',
#  'pineapple juice',
#  'dark rum',
#  'daikon',
#  'pork ribs',
#  'goji berries',
#  'oysters',
#  'salsa',
#  'demerara sugar',
#  'egg whites',
#  'fruit',
#  'frozen pastry puff sheets',
#  'mixed spice',
#  'parsnips',
#  'chili oil',
#  'brown mustard seeds',
#  'unsalted cashews',
#  'thai green curry paste',
#  'kecap manis',
#  'frozen broad beans',
#  'basil leaves',
#  'chili flakes',
#  'chicken tenderloin',
#  'creole style seasoning',
#  'condensed cheddar cheese soup',
#  'refried beans',
#  'grated jack cheese',
#  'egg yolks',
#  'asparagus',
#  'fresh leav spinach',
#  'cheese tortellini',
#  'cherry tomatoes',
#  'navy beans',
#  'nonfat milk',
#  'granny smith apples',
#  'lard',
#  'pecorino romano cheese',
#  'fresh fava bean',
#  'italian sausage',
#  'pasta sheets',
#  'spinach leaves',
#  'low-fat natural yogurt',
#  'Flora Cuisine',
#  'curry paste',
#  'bone-in chicken breasts',
#  'white hominy',
#  'dried chile peppers',
#  'frozen whipped topping',
#  'chocolate instant pudding',
#  'instant butterscotch pudding mix',
#  'graham cracker crumbs',
#  'fennel seeds',
#  'kalamata',
#  'kielbasa',
#  'celery ribs',
#  'ham',
#  'moong dal',
#  'capsicum',
#  'green mango',
#  'toasted sesame oil',
#  'tofu',
#  'short-grain rice',
#  'dried shiitake mushrooms',
#  'gari',
#  'Turkish bay leaves',
#  'dried chickpeas',
#  'semolina',
#  'vine ripened tomatoes',
#  'bittersweet chocolate',
#  'fat free yogurt',
#  'skim milk',
#  'angel food cake',
#  'unsweetened cocoa powder',
#  'instant espresso',
#  'organic chicken',
#  'anise',
#  'zinfandel',
#  'orange blossom honey',
#  'calimyrna figs',
#  'clove',
#  'plain whole-milk yogurt',
#  'reduced sodium soy sauce',
#  'beef stock',
#  'chuck roast',
#  'Corn Flakes Cereal',
#  'coleslaw',
#  'garlic salt',
#  'chili paste',
#  'red pepper flakes',
#  'kiwi',
#  'asian pear',
#  'chees fresco queso',
#  'swiss chard',
#  'veal cutlets',
#  'pasta',
#  'wakame',
#  'extra-lean ground beef',
#  'scallion greens',
#  'wonton wrappers',
#  'peeled fresh ginger',
#  'nonstick spray',
#  'chopped fresh thyme',
#  'chicken bones',
#  'green bell pepper, slice',
#  'anchovy fillets',
#  'crusty rolls',
#  'coconut oil',
#  'almond flour',
#  'coconut aminos',
#  'green peas',
#  'clams',
#  'boneless skinless chicken breast halves',
#  'seasoned rice wine vinegar',
#  'snow peas',
#  'hard-boiled egg',
#  'artichoke hearts',
#  'stuffing',
#  'coriander powder',
#  'maida flour',
#  'pita bread rounds',
#  'grated GruyГЁre cheese',
#  'udon',
#  'red miso',
#  'silken tofu',
#  'button mushrooms',
#  'whole peeled tomatoes',
#  'shredded Monterey Jack cheese',
#  'pickled jalapenos',
#  'broccoli rabe',
#  'parmigiano reggiano cheese',
#  'fontina',
#  'thai chile',
#  'peppercorns',
#  'refrigerated piecrusts',
#  'cream of chicken soup',
#  'frozen peas and carrots',
#  'low sodium chicken broth',
#  'pasta sauce',
#  'olive oil flavored cooking spray',
#  'frozen chopped spinach',
#  'part-skim ricotta cheese',
#  'manicotti shells',
#  'fettucine',
#  'parmesan cheese',
#  'chicken bouillon',
#  'chili paste with garlic',
#  'fresh veget',
#  'taco sauce',
#  'guacamole',
#  'salsa verde',
#  'condiments',
#  'pork shoulder roast',
#  'tortillas',
#  'rose petals',
#  'almonds',
#  'pistachios',
#  'chicken wings',
#  'drumstick',
#  'green chile',
#  'peeled tomatoes',
#  'chicken',
#  'chiles',
#  'adobo sauce',
#  'ancho powder',
#  'chipotle chile powder',
#  'Old El Paso Flour Tortillas',
#  'cranberry sauce',
#  'beer',
#  'chili sauce',
#  'beef rib short',
#  'miso paste',
#  'seaweed',
#  'dashi',
#  'fresh dill',
#  'yoghurt',
#  'myzithra',
#  'phyllo',
#  'kefalotyri',
#  'okra',
#  'cracker crumbs',
#  'Philadelphia Cream Cheese',
#  'crab meat',
#  'savoy cabbage',
#  'boneless chicken thighs',
#  'potato starch',
#  'cream of tartar',
#  'semi-sweet chocolate morsels',
#  'cake flour',
#  'ricotta cheese',
#  'serrano',
#  'steel-cut oats',
#  'hazelnuts',
#  'hazelnut oil',
#  'sweet cherries',
#  'fire roasted diced tomatoes',
#  'red kidnei beans, rins and drain',
#  'wasabi paste',
#  'black sesame seeds',
#  'Japanese soy sauce',
#  'fresh salmon',
#  'dried porcini mushrooms',
#  'dry red wine',
#  'hot water',
#  'fat free less sodium beef broth',
#  'cremini mushrooms',
#  'creole mustard',
#  'prepared horseradish',
#  'celery salt',
#  'shrimp and crab boil seasoning',
#  'turnip greens',
#  'butternut squash',
#  'apples',
#  'country ham',
#  'frozen edamame beans',
#  'whole kernel corn, drain',
#  'strong white bread flour',
#  'salted butter',
#  'sunflower oil',
#  'kalonji',
#  'instant yeast',
#  'fresh coriander',
#  'cooked white rice',
#  'mixed mushrooms',
#  'wood ear mushrooms',
#  'vegetables',
#  'taco seasoning',
#  'bell pepper',
#  'boneless skinless chicken breasts',
#  'shredded cheese',
#  'eau de vie',
#  'leaves',
#  'cane sugar',
#  'baking apples',
#  'salt and ground black pepper',
#  'sliced black olives',
#  'chopped green chilies',
#  'rosemary leaves',
#  'lean steak',
#  'Guinness Lager',
#  'dried rosemary',
#  'water chestnuts, drained and chopped',
#  'chinese cabbage',
#  'dipping sauces',
#  'lean ground pork',
#  'pico de gallo',
#  'cheese slices',
#  'chorizo',
#  'french bread',
#  'dried dillweed',
#  'red wine',
#  'lamb',
#  'plain yogurt',
#  'kale',
#  'Mexican beer',
#  'boneless beef short ribs',
#  'guajillo',
#  'saffron threads',
#  'fresh spinach',
#  'banana squash',
#  'cannellini beans',
#  'shortening',
#  'Franks Hot Sauce',
#  'pears',
#  'light pancake syrup',
#  'puff pastry',
#  'apple cider vinegar',
#  'mushroom powder',
#  'bone in chicken thighs',
#  'fresh bay leaves',
#  'cilantro',
#  'skinless chicken breasts',
#  'light sour cream',
#  'fava beans',
#  'fresh tarragon',
#  'kidney beans',
#  'orzo pasta',
#  'dri leav thyme',
#  'wasabi',
#  'jumbo shrimp',
#  'sticky rice',
#  'white sesame seeds',
#  'chopped almonds',
#  'baby arugula',
#  'tequila',
#  'margarita mix',
#  'crust',
#  'grits',
#  'pecan halves',
#  'corn syrup',
#  'superfine sugar',
#  'blackberries',
#  'whiskey',
#  'luke warm water',
#  'active dry yeast',
#  'fresh mint',
#  'jamaican jerk season',
#  'pineapple preserves',
#  'chicken drumsticks',
#  'pitas',
#  'goat cheese',
#  'gingerroot',
#  'rib eye steaks',
#  'hot bean paste',
#  'medjool date',
#  'diced bell pepper',
#  'cream',
#  'smoked paprika',
#  'reduced fat milk',
#  'smoked trout',
#  'garlic puree',
#  'green cardamom pods',
#  'tomato purГ©e',
#  'pickled jalapeno peppers',
#  'romaine lettuce leaves',
#  'crema mexicana',
#  'chile sauce',
#  'queso fresco',
#  'Boston lettuce',
#  'persian cucumber',
#  'peanut butter',
#  'rice paper',
#  'Korean chile flakes',
#  'red chile powder',
#  'boneless chicken breast',
#  'cashew nuts',
#  'kashmiri chile',
#  'kasuri methi',
#  'mustard oil',
#  'ginger paste',
#  'cinnamon',
#  'tomato ketchup',
#  'pecan pie',
#  'tostada shells',
#  'grouper',
#  'corn kernels',
#  'ricotta salata',
#  'pecorino cheese',
#  'grana padano',
#  'kaffir lime leaves',
#  'corn',
#  'soba noodles',
#  'galangal',
#  'green curry paste',
#  'bamboo shoots',
#  'chopped nuts',
#  'bourbon whiskey',
#  'ketchup',
#  'rhubarb',
#  'liquid',
#  'store bought low sodium chicken stock',
#  'safflower oil',
#  'jeera',
#  'cardamom',
#  'crema',
#  'salmon steaks',
#  'jam',
#  'karashi',
#  'spring onions',
#  'free range egg',
#  'jicama',
#  'water chestnuts',
#  'diced celery',
#  'shredded sharp cheddar cheese',
#  'dinner rolls',
#  'cactus pad',
#  'fenugreek seeds',
#  'cauliflower flowerets',
#  'boiling potatoes',
#  'baby spinach',
#  'tuna steaks',
#  'spices',
#  'octopuses',
#  'vidalia onion',
#  'smoked gouda',
#  'small red potato',
#  'tuna',
#  'fat-free refried beans',
#  'low-fat milk',
#  'fresh lime',
#  'ground white pepper',
#  'BertolliВ® Classico Olive Oil',
#  'bacon, crisp-cooked and crumbled',
#  'bertolli vineyard premium collect marinara with burgundi wine sauc',
#  'bread crumb fresh',
#  'margarita salt',
#  '(    oz.) tomato sauce',
#  'ground veal',
#  'italian seasoning mix',
#  'beef',
#  'solid pack pumpkin',
#  'fresh thyme leaves',
#  'whole grain thin spaghetti',
#  'grapeseed oil',
#  'organic sugar',
#  'dried cherry',
#  'straw mushrooms',
#  'vidalia',
#  'haricots verts',
#  'wax beans',
#  'prosciutto',
#  'romano cheese',
#  'cooked shrimp',
#  'crabmeat',
#  'strawberries',
#  'green peppercorns',
#  'pork loin chops',
#  'chipotle peppers',
#  'blueberri preserv',
#  'filet',
#  'thyme leaves',
#  'coffee beans',
#  'vegan margarine',
#  'pork shoulder',
#  'parsley leaves',
#  'fresh raspberries',
#  'frozen whole kernel corn',
#  'wish bone guacamol ranch dress',
#  'torn romain lettuc leav',
#  'russet potatoes',
#  'mexican chorizo',
#  'colby cheese',
#  'half & half',
#  'dry vermouth',
#  'canned low sodium chicken broth',
#  'roasted salted cashews',
#  'fresh lemon',
#  'toasted sesame seeds',
#  'paneer cheese',
#  'lemon grass',
#  'Thai fish sauce',
#  ...]

# %% [markdown]
# Exercise 7.3

# %%
def make_list(row):
    ingredients = []
    col = row.columns[3:]
    for c in col:
        for el in row[c]:
            if (el==1) and not (c in ingredients):
                ingredients.append(c)
    return ingredients

new_recipes = [] # Создаём пустой список для хранения итоговой структуры
for current_id in ids: # Организуем цикл с параметром current_id
    cuisine = df[df['id'] == current_id]['cuisine'].iloc[0] 
    # Получаем значение соответствующей кухни, применив фильтр по текущему значению параметра цикла к DataFrame;
    current_ingredients = make_list(df[df['id'] == current_id]) 
    # Получаем перечень ингредиентов, входящих в состав текущего блюда
    current_recipe = {'cuisine': cuisine,
                      'id': int(current_id),
                      'ingredients': current_ingredients} 
    # Создаём текущий словарь
    new_recipes.append(current_recipe) # Добавляем созданный словарь к списку

# %%
ids = list(df['id'].unique())
ingredients = list(df.columns)[3:] # Создаем список уникальных значений ингредиентов
def make_list(row): # Определяем имя функции и передаваемые аргументы
    ingredient_list=[] # Создаём пустой список ингредиентов текущего блюда
    for ingredient in ingredients: # Последовательно перебираем ингредиенты из реестра
        if row[ingredient].item()==1: # Если текущий ингредиент входит в состав текущего блюда
            ingredient_list.append(ingredient) # Добавляем ингредиент в список ингредиентов текущего блюда
    return ingredient_list # Возвращаем сформированный список ингредиентов

# Создаём пустой список для хранения итоговой структуры
new_recipes = []
# Организуем цикл с параметром current_id
for current_id in ids:
    # Получаем значение соответствующей кухни, применив фильтр по текущему значению параметра цикла к DataFrame;
    cuisine = df[df['id'] == current_id]['cuisine'].iloc[0]
    # Получаем перечень ингредиентов, входящих в состав текущего блюда
    current_ingredients = make_list(df[df['id'] == current_id])
    # Создаём текущий словарь
    current_recipe = {'cuisine': cuisine, 'id': int(current_id), 'ingredients': current_ingredients}
    # Добавляем созданный словарь к списку
    new_recipes.append(current_recipe)
print(new_recipes)
# Out:
# [{'cuisine': 'greek', 'id': 10259, 'ingredients': ['romaine lettuce', 'black olives', 'grape tomatoes', 'garlic', 'pepper', 'purple onion', 'seasoning', 'garbanzo beans', 'feta cheese crumbles']}, {'cuisine': 'southern_us', 'id': 25693, 'ingredients': ['plain flour', 'ground pepper', 'salt', 'tomatoes', 'ground black pepper', 'thyme', 'eggs', 'green tomatoes', 'yellow corn meal', 'milk', 'vegetable oil']}, {'cuisine': 'filipino', 'id': 20130, 'ingredients': ['pepper', 'salt', 'eggs', 'mayonaise', 'cooking oil', 'green chilies', 'grilled chicken breasts', 'garlic powder', 'yellow onion', 'soy sauce', 'butter', 'chicken livers']}, {'cuisine': 'indian', 'id': 22213, 'ingredients': ['salt', 'vegetable oil', 'water', 'wheat']}, {'cuisine': 'indian', 'id': 13162, 'ingredients': ['salt', 'milk', 'butter', 'water', 'black pepper', 'shallots', 'cornflour', 'cayenne pepper', 'onions', 'garlic paste', 'lemon juice', 'chili powder', 'passata', 'oil', 'ground cumin', 'boneless chicken skinless thigh', 'garam masala', 'double cream', 'natural yogurt', 'bay leaf']}, {'cuisine': 'jamaican', 'id': 6602, 'ingredients': ['plain flour', 'salt', 'eggs', 'milk', 'butter', 'sugar', 'fresh ginger root', 'ground cinnamon', 'vanilla extract', 'ground ginger', 'powdered sugar', 'baking powder']}, {'cuisine': 'spanish', 'id': 42779, 'ingredients': ['garlic', 'pepper', 'salt', 'bay leaf', 'olive oil', 'medium shrimp', 'chopped cilantro', 'jalapeno chilies', 'flat leaf parsley', 'skirt steak', 'white vinegar', 'sea salt', 'chorizo sausage']}, {'cuisine': 'italian', 'id': 3735, 'ingredients': ['eggs', 'sugar', 'vanilla extract', 'baking powder', 'olive oil', 'pistachio nuts', 'white almond bark', 'flour', 'almond extract', 'dried cranberries']}, {'cuisine': 'mexican', 'id': 16903, 'ingredients': ['purple onion', 'salt', 'ground black pepper', 'olive oil', 'jalapeno chilies', 'fresh pineapple', 'pork', 'poblano peppers', 'corn tortillas', 'cheddar cheese', 'iceberg lettuce', 'lime', 'chopped cilantro fresh']}, {'cuisine': 'italian', 'id': 12734, 'ingredients': ['garlic', 'flat leaf parsley', 'chopped tomatoes', 'fresh basil', 'extra-virgin olive oil', 'kosher salt']}, {'cuisine': 'italian', 'id': 5875, 'ingredients': ['black olives', 'garlic', 'pepper', 'olive oil', 'pimentos', 'sweet pepper', 'dried oregano', 'sharp cheddar cheese', 'swiss cheese', 'provolone cheese', 'canola oil', 'mushrooms', 'sausages']}, {'cuisine': 'chinese', 'id': 45887, 'ingredients': ['garlic', 'water', 'sugar', 'canola oil', 'low sodium soy sauce', 'fresh ginger', 'dry mustard', 'green beans', 'white pepper', 'sesame oil', 'scallions', 'Shaoxing wine', 'ground turkey', 'crushed red pepper flakes', 'corn starch']}, {'cuisine': 'italian', 'id': 2698, 'ingredients': ['flat leaf parsley', 'extra-virgin olive oil', 'Italian parsley leaves', 'walnuts', 'hot red pepper flakes', 'fresh lemon juice', 'trout fillet', 'garlic cloves', 'chipotle chile', 'fine sea salt']}, {'cuisine': 'mexican', 'id': 41995, 'ingredients': ['garlic', 'salt', 'ground black pepper', 'black pepper', 'onions', 'chili powder', 'ground cumin', 'ground cinnamon', 'olive oil', 'kosher salt', 'crushed red pepper flakes', 'fresh cilantro', 'ground coriander', 'plum tomatoes', 'avocado', 'lime juice', 'flank steak']}, {'cuisine': 'italian', 'id': 31908, 'ingredients': ['salt', 'ground black pepper', 'butter', 'fresh parmesan cheese', 'all-purpose flour', 'fat free less sodium chicken broth', 'chopped fresh chives', 'gruyere cheese', 'bacon slices', 'gnocchi', 'fat free milk', 'cooking spray']}, {'cuisine': 'indian', 'id': 24717, 'ingredients': ['tomatoes', 'onions', 'garam masala', 'tumeric', 'vegetable stock', 'naan', 'red lentils', 'red chili peppers', 'spinach', 'sweet potatoes']}, {'cuisine': 'british', 'id': 34466, 'ingredients': ['greek yogurt', 'lemon curd', 'confectioners sugar', 'raspberries']}, {'cuisine': 'italian', 'id': 1420, 'ingredients': ['mayonaise', 'italian seasoning', 'broiler-fryer chicken', 'zesty it ...

# %% [markdown]
# serialization

# %%
# Функция dumps() модуля json сериализирует объект Python в строку формата JSON
new_recipes = json.dumps(new_recipes) 

# Откроем файл new_recipes.json для записи
with open("data/new_recipes.json", "w") as write_file: 
    # Записываем содержимое подготовленные данные в файл
    write_file.write(new_recipes)
