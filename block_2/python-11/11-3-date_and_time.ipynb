# %% [markdown]
# import libraries

# %%
import pandas as pd, numpy as np

# %% [markdown]
# read csv property file

# %%
melb_data = pd.read_csv('data/melb_data_ps.csv', sep=',')
melb_data.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...    1     202.0         126.0       1970
# 1  4/02/2016       2.5  ...    0     156.0          79.0       1900
# 2  4/03/2017       2.5  ...    0     134.0         150.0       1900
# 3  4/03/2017       2.5  ...    1      94.0         126.0       1970
# 4  4/06/2016       2.5  ...    2     120.0         142.0       2014
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %% [markdown]
# create a copy of the property file

# %%
melb_df = melb_data.copy()
melb_df.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...    1     202.0         126.0       1970
# 1  4/02/2016       2.5  ...    0     156.0          79.0       1900
# 2  4/03/2017       2.5  ...    0     134.0         150.0       1900
# 3  4/03/2017       2.5  ...    1      94.0         126.0       1970
# 4  4/06/2016       2.5  ...    2     120.0         142.0       2014
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %% [markdown]
# convert date: from dd/mm/yyyy -> to standard datetime of yyyy/mm/dd

# %%
melb_df['Date'] = pd.to_datetime(melb_df['Date'], dayfirst=True)
display(melb_df['Date'])
# Out:
# 0       2016-12-03
# 1       2016-02-04
# 2       2017-03-04
# 3       2017-03-04
# 4       2016-06-04
#            ...
# 13575   2017-08-26
# 13576   2017-08-26
# 13577   2017-08-26
# 13578   2017-08-26
# 13579   2017-08-26
# Name: Date, Length: 13580, dtype: datetime64[ns]

# %% [markdown]
# using accessory dt.? can find useful information \
# .dt.year

# %%
years_sold = melb_df['Date'].dt.year
print('Min year sold:', years_sold.min())
print('Max year sold:', years_sold.max())
print('Mode year sold:', years_sold.mode()[0])
# Out:
# Min year sold: 2016
# Max year sold: 2017
# Mode year sold: 2017

# %% [markdown]
# which are the most popular sale months?

# %%
melb_df['MonthSale'] = melb_df['Date'].dt.month
melb_df['MonthSale'].value_counts(normalize=True) * 100
# Out:
# MonthSale
# 5     14.941090
# 7     14.594993
# 9     13.586156
# 6     13.475700
# 8     11.413844
# 11     8.203240
# 4      6.988218
# 3      4.992636
# 12     4.469809
# 10     4.057437
# 2      3.262150
# 1      0.014728
# Name: proportion, dtype: float64

# %% [markdown]
# or can use the mode() function to find the most popular month

# %%
melb_df['MonthSale'] = melb_df['Date'].dt.month
melb_df['MonthSale'].mode()
# Out:
# 0    5
# Name: MonthSale, dtype: int32

# %% [markdown]
# working with time intervals

# %%
delta_days = melb_df['Date'] - pd.to_datetime('2016-01-01') 
display(delta_days.dt.days)
# Out:
# 0        337
# 1         34
# 2        428
# 3        428
# 4        155
#         ...
# 13575    603
# 13576    603
# 13577    603
# 13578    603
# 13579    603
# Name: Date, Length: 13580, dtype: int64

# %% [markdown]
# age of the property: from the day it's build, to the day it's sold

# %%
melb_df['BuildingAge'] = melb_df['Date'].dt.year - melb_df['YearBuilt']
display(melb_df['BuildingAge'])
# Out:
# 0         46
# 1        116
# 2        117
# 3         47
# 4          2
#         ...
# 13575     36
# 13576     22
# 13577     20
# 13578     97
# 13579     97
# Name: BuildingAge, Length: 13580, dtype: int64

# %% [markdown]
# don't duplicate data: BuildingAge > YearBuilt

# %%
melb_df = melb_df.drop('YearBuilt', axis=1)
melb_df
# Out:
#        index         Suburb           Address  Rooms Type      Price Method  \
# 0          0     Abbotsford      85 Turner St      2    h  1480000.0      S
# 1          1     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          2     Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          3     Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          4     Abbotsford       55a Park St      4    h  1600000.0     VB
# ...      ...            ...               ...    ...  ...        ...    ...
# 13575  13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
# ...

# %% [markdown]
# Exercise 3.3: \
# (a) create WeekDaySale

# %%
melb_df['WeekDaySale'] = melb_df['Date'].dt.day_of_week
display(melb_df['WeekDaySale'])
# Out:
# 0        5
# 1        3
# 2        5
# 3        5
# 4        5
#         ..
# 13575    5
# 13576    5
# 13577    5
# 13578    5
# 13579    5
# Name: WeekDaySale, Length: 13580, dtype: int32

# %%
melb_df['WeekDaySale'].value_counts()
# Out:
# WeekDaySale
# 5    11759
# 6     1063
# 0      597
# 1      133
# 3       28
# Name: count, dtype: int64

# %% [markdown]
# (b) find name of the day

# %%
melb_df['WeekDayNameSale'] = melb_df['Date'].dt.day_name()
display(melb_df['WeekDayNameSale'])
# Out:
# 0        Saturday
# 1        Thursday
# 2        Saturday
# 3        Saturday
# 4        Saturday
#            ...
# 13575    Saturday
# 13576    Saturday
# 13577    Saturday
# 13578    Saturday
# 13579    Saturday
# Name: WeekDayNameSale, Length: 13580, dtype: object

# %% [markdown]
# (c) find how many properties were sold on Saturday and Sunday

# %%
weekend_count = melb_df[(melb_df['WeekDayNameSale'] == 'Saturday') | (melb_df['WeekDayNameSale'] == 'Sunday')].shape[0]
weekend_count
# Out:
# 12822

# %% [markdown]
# new data set for ex3.4-3.6

# %%
usa_et_data = pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv', sep=',')
usa_et_data
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %% [markdown]
# firstly, find the information on the table

# %%
usa_et_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             18215 non-null  object
#  1   Colors Reported  2882 non-null   object
#  2   Shape Reported   15597 non-null  object
#  3   State            18241 non-null  object
#  4   Time             18241 non-null  object
# dtypes: object(5)
# memory usage: 712.7+ KB

# %% [markdown]
# secondly, find the records with missing values

# %%
usa_et_data.isna().sum()
# Out:
# City                  26
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %% [markdown]
# thirdly, fill in the blanks

# %%
usa_et_data = usa_et_data.fillna(0)

# %% [markdown]
# display the changed data set

# %%
usa_et_data
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca               0       TRIANGLE    NY
# 1               Willingboro               0          OTHER    NJ
# 2                   Holyoke               0           OVAL    CO
# 3                   Abilene               0           DISK    KS
# 4      New York Worlds Fair               0          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park               0       TRIANGLE    IL
# 18237           Spirit Lake               0           DISK    IA
# 18238           Eagle River               0              0    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor               0           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %% [markdown]
# Exercise 3.4: which year has the highest number of observations of extra-terrestrials?

# %%
#convert Time to_datetime, create a new column - Year
usa_et_data['Time'] = pd.to_datetime(usa_et_data['Time'])

#create a new column - Year
usa_et_data['Year'] = usa_et_data['Time'].dt.year
usa_et_data.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca               0       TRIANGLE    NY
# 1           Willingboro               0          OTHER    NJ
# 2               Holyoke               0           OVAL    CO
# 3               Abilene               0           DISK    KS
# 4  New York Worlds Fair               0          LIGHT    NY
#
#                  Time  Year
# 0 1930-06-01 22:00:00  1930
# 1 1930-06-30 20:00:00  1930
# 2 1931-02-15 14:00:00  1931
# 3 1931-06-01 13:00:00  1931
# 4 1933-04-18 19:00:00  1933

# %%
usa_et_data['Year'].value_counts(normalize=True) * 100
# Out:
# Year
# 1999    15.207500
# 2000    14.445480
# 1998     9.555397
# 1995     7.368017
# 1997     6.781426
#           ...
# 1936     0.010964
# 1930     0.010964
# 1935     0.005482
# 1934     0.005482
# 1933     0.005482
# Name: proportion, Length: 68, dtype: float64

# %% [markdown]
# Exercise 3.5: find the average time interval between each observation in the state of Nevada in days

# %%
#let's convert Time to all

#create a new column - Month
usa_et_data['Month'] = usa_et_data['Time'].dt.month

#create a new column - Day
usa_et_data['Day'] = usa_et_data['Time'].dt.day

#create a new column - Date
usa_et_data['Date'] = usa_et_data['Time'].dt.date

usa_et_data.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca               0       TRIANGLE    NY
# 1           Willingboro               0          OTHER    NJ
# 2               Holyoke               0           OVAL    CO
# 3               Abilene               0           DISK    KS
# 4  New York Worlds Fair               0          LIGHT    NY
#
#                  Time  Year  Month  Day        Date
# 0 1930-06-01 22:00:00  1930      6    1  1930-06-01
# 1 1930-06-30 20:00:00  1930      6   30  1930-06-30
# 2 1931-02-15 14:00:00  1931      2   15  1931-02-15
# 3 1931-06-01 13:00:00  1931      6    1  1931-06-01
# 4 1933-04-18 19:00:00  1933      4   18  1933-04-18

# %% [markdown]
# find the data on Nevada only

# %%
nv_only = usa_et_data[usa_et_data['State'] == 'NV']
nv_only.head()
# Out:
#            City Colors Reported Shape Reported State                Time  \
# 76    Las Vegas               0           DISK    NV 1947-07-15 10:00:00
# 172  Nellis AFB               0           DISK    NV 1952-02-17 18:00:00
# 565      Fallon               0           OVAL    NV 1959-09-15 00:00:00
# 566   Goldfield               0          LIGHT    NV 1959-09-15 01:00:00
# 613           0               0           DISK    NV 1960-07-01 12:00:00
#
#      Year  Month  Day        Date
# 76   1947      7   15  1947-07-15
# 172  1952      2   17  1952-02-17
# 565  1959      9   15  1959-09-15
# 566  1959      9   15  1959-09-15
# 613  1960      7    1  1960-07-01

# %% [markdown]
# find the difference between each observation in days, \
# and then find the average

# %%
dif_date = nv_only['Date'].diff()
dif_date_in_days = dif_date.dt.days
avg_maybe = dif_date_in_days.mean()
print(round(avg_maybe, 0))
# Out:
# 69.0
