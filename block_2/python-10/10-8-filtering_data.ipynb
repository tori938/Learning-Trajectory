# %%
import pandas as pd, numpy as np

# %% [markdown]
# READ THE PROPERTY CSV FILE

# %%
melb_data = pd.read_csv('data/melb_data.csv', sep=',')
melb_data
# Out:
#        index         Suburb           Address  Rooms Type      Price Method  \
# 0          0     Abbotsford      85 Turner St      2    h  1480000.0      S
# 1          1     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          2     Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          3     Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          4     Abbotsford       55a Park St      4    h  1600000.0     VB
# ...      ...            ...               ...    ...  ...        ...    ...
# 13575  13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
# ...

# %%
big_value = melb_data['Price'] > 2000000
display(big_value)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13575    False
# 13576    False
# 13577    False
# 13578     True
# 13579    False
# Name: Price, Length: 13580, dtype: bool

# %%
display(melb_data[big_value].head())
# Out:
#     index       Suburb               Address  Rooms Type      Price Method  \
# 80     80  Albert Park  112 Beaconsfield Pde      3    h  2850000.0     PI
# 85     85  Albert Park     104 Richardson St      4    h  2300000.0      S
# 88     88  Albert Park        29 Faussett St      2    h  2120000.0      S
# 92     92  Albert Park           2 Dundas Pl      3    h  2615000.0      S
# 93     93  Albert Park          23 Finlay St      5    h  2100000.0      S
#
#      SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  \
# 80    Buxton   4/03/2017       3.3  ...  0.0     211.0         198.0
# 85  Marshall   7/05/2016       3.3  ...  1.0     153.0         180.0
# 88      Greg  10/09/2016       3.3  ...  1.0     199.0         107.0
# 92    Cayzer  10/12/2016       3.3  ...  1.0     177.0         181.0
# 93      Greg  10/12/2016       3.3  ...  1.0     237.0         126.0
#
#     YearBuilt   CouncilArea  Lattitude  Longtitude             Regionname  \
# ...

# %% [markdown]
# Hе обязательно заносить маску в отдельную переменную — можно сразу вставлять условие в операцию индексации DataFrame.

# %%
melb_data[melb_data['Price'] > 2000000]
# Out:
#        index          Suburb               Address  Rooms Type      Price  \
# 80        80     Albert Park  112 Beaconsfield Pde      3    h  2850000.0
# 85        85     Albert Park     104 Richardson St      4    h  2300000.0
# 88        88     Albert Park        29 Faussett St      2    h  2120000.0
# 92        92     Albert Park           2 Dundas Pl      3    h  2615000.0
# 93        93     Albert Park          23 Finlay St      5    h  2100000.0
# ...      ...             ...                   ...    ...  ...        ...
# 13521  13521  Port Melbourne          44 Garton St      4    t  2455000.0
# 13523  13523         Prahran        69 Greville St      4    h  2668000.0
# 13553  13553    Surrey Hills          20 Albert Cr      4    h  2720000.0
# 13555  13555    Surrey Hills              3 Oak St      4    h  3100000.0
# 13578  13578    Williamstown          96 Verdon St      4    h  2500000.0
#
#       Method   SellerG        Date  Distance  ...  Car  Landsize  \
# ...

# %% [markdown]
# Найдём количество зданий с тремя комнатами. \
# Для этого отфильтруем таблицу по условию: обратимся к результирующей таблице по столбцу Rooms и найдём число строк в ней с помощью атрибута shape.

# %%
melb_data[melb_data['Rooms'] == 3].shape[0]
# Out:
# 5881

# %% [markdown]
# Усложним прошлый пример и найдём число трёхкомнатных домов с ценой менее 300 тысяч.

# %%
melb_data[(melb_data['Rooms'] == 3) & (melb_data['Price'] < 300000)].shape[0]
# Out:
# 3

# %% [markdown]
# теперь нас будут интересовать дома с ценой менее 300 тысяч, у которых либо число комнат равно 3 либо площадь домов более 100 квадратных метров

# %%
melb_data[((melb_data['Rooms'] == 3) | (melb_data['BuildingArea'] > 100)) & (melb_data['Price'] < 300000)].shape[0]
# Out:
# 68

# %% [markdown]
# Фильтрацию часто сочетают со статистическими методами. \
# Давайте найдём максимальное количество комнат в таунхаусах.

# %%
melb_data[melb_data['Type'] == 't']['Rooms'].max()
# Out:
# 5

# %% [markdown]
# найдём медианную площадь здания у объектов, чья цена выше средней

# %%
mean_price = melb_data['Price'].mean()
melb_data[melb_data['Price'] > mean_price]['BuildingArea'].median()
# Out:
# 126.0

# %% [markdown]
# EXERCISE 8.1: NUMBER OF PROPERTIES WITH NO BATHROOMS

# %% [markdown]
# FIRST, FIND THE LIST OF COLUMNS

# %%
column_names = list(melb_data.columns.values)
column_names
# Out:
# ['index',
#  'Suburb',
#  'Address',
#  'Rooms',
#  'Type',
#  'Price',
#  'Method',
#  'SellerG',
#  'Date',
#  'Distance',
#  'Postcode',
#  'Bedroom',
#  'Bathroom',
#  'Car',
#  'Landsize',
#  'BuildingArea',
#  'YearBuilt',
#  'CouncilArea',
#  'Lattitude',
#  'Longtitude',
#  'Regionname',
#  'Propertycount',
#  'Coordinates']

# %%
melb_data[melb_data['Bathroom'] == 0].shape[0]
# Out:
# 34

# %% [markdown]
# EXERCISE 8.2: HOW MANY PROPERTIES >£3M WERE SOLD BY NELSON?

# %%
melb_data[(melb_data['SellerG'] == 'Nelson') & (melb_data['Price'] > 3000000)].shape[0]
# Out:
# 5

# %% [markdown]
# EXERCISE 8.3: WHAT IS THE MIN PRICE OF LAND WITH NO PROPERTY ON IT?

# %%
only_land = melb_data[melb_data['BuildingArea'] == 0].shape[0]
y = melb_data[melb_data['BuildingArea'] == 0]['Price'].min()
print(only_land, y, sep='\n')
# Out:
# 17
# 412500.0

# %% [markdown]
# EXERCISE 8.4: FIND THE AVERAGE PRICE OF PROPERTY THAT COSTS LESS THAN £1M, AND ONES THAT HAVE MORE THAN 5 ROOMS OR THE PROPERTY WAS BUILD AFTER 2015?

# %%
no_of_properties = melb_data[((melb_data['Rooms'] > 5) | (melb_data['YearBuilt'] > 2015)) & (melb_data['Price'] < 1000000)]
#no_of_properties --> it's a new dataframe, essentially, from which I can pick any column I want

avg_price_of_properties = no_of_properties['Price'].mean()
round(avg_price_of_properties, 0)
# Out:
# 769239.0

# %% [markdown]
# EXERCISE 8.5: \
# В каком районе Мельбурна чаще всего продаются виллы и коттеджи (тип здания — h) с ценой меньше трёх миллионов?

# %%
two_popular = melb_data[(melb_data['Type'] == 'h') & (melb_data['Price'] < 3000000)]
two_popular

two_popular['Regionname'].mode()
# Out:
# 0    Northern Metropolitan
# Name: Regionname, dtype: object

# %%
melb_data['Type'].value_counts()
# Out:
# Type
# h    9449
# u    3017
# t    1114
# Name: count, dtype: int64
